# %%
import yaml
import glob
import os
from pathlib import Path
from typing import Dict, Set, List

# Configure the base path for TO&E files
BASE_PATH = Path("../database/toe")

def load_toe_files() -> Dict[str, dict]:
    """Load all TO&E YAML files and return a dictionary of {id: data}"""
    toe_files = {}
    for yaml_file in BASE_PATH.rglob("*.yaml"):
        with open(yaml_file, encoding='UTF-8') as f:
            data = yaml.safe_load(f)
            if data and 'id' in data:
                toe_files[data['id']] = data
    return toe_files

# %%
def check_circular_references(toe_data: Dict[str, dict]) -> List[str]:
    """Check for circular references in TO&E definitions"""
    def check_unit(unit_id: str, visited: Set[str]) -> bool:
        if unit_id in visited:
            return True
        if unit_id not in toe_data:
            return False
            
        visited.add(unit_id)
        unit = toe_data[unit_id]
        
        if 'subunits' in unit and unit['subunits']:
            for subunit_id in unit['subunits']:
                if check_unit(subunit_id, visited.copy()):
                    return True
        return False
    
    circular_refs = []
    for unit_id in toe_data:
        if check_unit(unit_id, set()):
            circular_refs.append(unit_id)
    return circular_refs

# %%
def find_next_id(prefix: str = "TOEWG") -> str:
    """Find the next available ID number for a given prefix, including gaps in the sequence"""
    toe_data = load_toe_files()
    existing_ids = sorted([int(id.replace(prefix, "")) for id in toe_data.keys() 
                         if id.startswith(prefix)])
    
    if not existing_ids:
        return f"{prefix}000001"
    
    # Find first gap in sequence
    prev_id = 0
    for current_id in existing_ids:
        if current_id - prev_id > 1:
            return f"{prefix}{(prev_id + 1):06d}"
        prev_id = current_id
    
    # If no gaps found, use next number after highest
    return f"{prefix}{(existing_ids[-1] + 1):06d}"

# Example usage
print(f"Next available TOEWG ID: {find_next_id()}")
# Out:
# Next available TOEWG ID: TOEWG000021

# %%
# Load and analyze TO&E data
toe_data = load_toe_files()

print("=== TO&E Database Analysis ===")
print(f"Total units: {len(toe_data)}\n")

print("=== Unit List ===")
for unit_id, unit in toe_data.items():
    print(f"{unit_id}: {unit['name']}")

print("\n=== Circular Reference Check ===")
circular_refs = check_circular_references(toe_data)
if circular_refs:
    print("Warning: Circular references found in:")
    for ref in circular_refs:
        print(f"- {ref}")
else:
    print("No circular references found.")
# Out:
# === TO&E Database Analysis ===
# Total units: 88
#
# === Unit List ===
# TOEWG000017: Schwere Jäger Battalion
# TOEWG000006: Panzerbattalion
# TOEWG000007: Panzergrenadier Battalion
# TOEWG000217: Schwere Jäger Battalion
# TOEWG000205: le. Jägerkompanie
# TOEWG000204: le. Jägerkompanie Truppe
# TOEWG000005: Panzergrenadier Kompanie (Marder)
# TOEWG000105: Panzergrenadier Kompanie (MTW)
# TOEWG000004: Panzergrenadier Kompanie Truppe (Marder)
# TOEWG000104: Panzergrenadier Kompanie Truppe (MTW)
# TOEWG000010: Panzer Kompanie
# TOEWG000009: Panzer Kompanie Zug
# TOEWG000019: Panzermorser Batterie
# TOEWG000020: Panzermorser Zug Truppe
# TOEWG000220: le. Jägerkompanie
# TOEWG000221: Schwere Kompanie Truppe
# TOEWG000011: Stabskompanie
# TOEWG000015: Engineering Platoon
# TOEWG000014: Fernmeldezug
# TOEWG000016: Kompanieführungs Zug
# TOEWG000201: le. Jägergruppe
# TOEWG000203: le. Jäger Zug
# TOEWG000202: le. Jäger Zugtruppe
# TOEWG000001: Panzergrenadier Gruppe (Marder)
# TOEWG000101: Panzergrenadier Gruppe (MTW)
# TOEWG000003: Panzergrenadier Zug (Marder)
# TOEWG000103: Panzergrenadier Zug (MTW)
# TOEWG000002: Panzergrenadier Zug Truppe (Marder)
# TOEWG000102: Panzergrenadier Zug Truppe (MTW)
# TOEWG000012: Panzer Gruppe
# TOEWG000018: Panzermorser Zug
# TOEWG000008: Panzer Zug
# TOEWG000013: Supply Platoon
# TOEEG010204: Howitzer Battalion HQ
# TOEEG010215: Howitzer Battalion (SP, 122mm)
# TOEEG010205: Howitzer Battalion (Towed, 122mm)
# TOEEG000007: Motor Rifle Battalion (BMP)
# TOEEG010007: Motor Rifle Battalion (BTR)
# TOEEG000006: Motor Rifle Battalion HQ (BMP)
# TOEEG010006: Motor Rifle Battalion HQ (BTR)
# TOEEG001008: Tank Battalion HQ (Old)
# TOEEG001007: Tank Battalion (Old)
# TOEEG002007: Tank Battalion (Old, TR)
# TOEEG003006: Aufklarungskompanie
# TOEEG003005: Aufklarungskompanie-Trupp
# TOEEG003203: FRA Battery
# TOEEG000213: Howitzer Battery HQ (SP)
# TOEEG000202: Howitzer Battery HQ (Towed, 122mm)
# TOEEG000214: Howitzer Battery (SP, 122mm)
# TOEEG000203: Howitzer Battery (Towed, 122mm)
# TOEEG000011: Mortar Battery
# TOEEG000010: Mortar Battery HQ
# TOEEG000005: Motor Rifle Company (BMP)
# TOEEG010005: Motor Rifle Company (BTR)
# TOEEG000004: Motor Rifle Company HQ (BMP)
# TOEEG010004: Motor Rifle Company HQ (BTR)
# TOEEG003103: PALR Battery
# TOEEG003102: Battery HQ
# TOEEG001002: Tank Company HQ (Old)
# TOEEG001003: Tank Company (Old, MRR)
# TOEEG002003: Tank Company (Old, TR)
# TOEEG000013: Technical Section
# TOEEG000050: Transport Section
# TOEEG003002: Aufkl.-Gruppe (SPW)
# TOEEG003001: Aufkl.-Gruppe (SPz)
# TOEEG003004: Aufkl.-Zug (SPW)
# TOEEG003003: Aufkl.-Zug (SPz)
# TOEEG003202: Fla-SFL Zug
# TOEEG003201: Fla-SFL Zug
# TOEEG000212: Howitzer Platoon (SP, 122mm)
# TOEEG000201: Howitzer Platoon (Towed, 122mm)
# TOEEG000008: Mortar Platoon
# TOEEG000009: Transport Section
# TOEEG000003: Motor Rifle Platoon (BMP)
# TOEEG010003: Motor Rifle Platoon (BTR)
# TOEEG000002: Motor Rifle Platoon HQ (BMP)
# TOEEG010002: Motor Rifle Platoon HQ (BMP)
# TOEEG000001: Motor Rifle Squad (BMP)
# TOEEG010001: Motor Rifle Squad (BTR)
# TOEEG003101: PALR Zug (SPW)
# TOEEG000014: Signal Platoon
# TOEEG000012: Signal Platoon
# TOEEG000030: Supply Platoon
# TOEEG001001: Tank Platoon (Old, MRR)
# TOEEG002001: Tank Platoon (Old, TR)
# TOEEG020001: Motor Rifle Regiment (BMP)
# TOEEG020002: Motor Rifle Regiment (BTR)
# TOEEG020003: Tank Regiment
#
# === Circular Reference Check ===
# No circular references found.
